# %%
import pandas as pd
df = pd.read_csv('employees.csv')
size_in_bytes = df.memory_usage(deep=True).sum()
num_records = len(df)
print(f"Approx. data size: {size_in_bytes}")
print(f"Number of records: {num_records}")
# Out:
# Approx. data size: 11756341
# Number of records: 20000
